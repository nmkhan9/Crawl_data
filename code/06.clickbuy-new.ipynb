# %%
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %%
link_set = set()
products = []

# %%
def getlink(soup):
    items = soup.find_all('div', class_='list-products__item')
    links = []
    for item in items:
        a_tag = item.find('a')
        if a_tag and a_tag.get('href'):
            link = 'https://clickbuy.com.vn' + a_tag['href']
            links.append(link)
    return links

# %%
semaphore = asyncio.Semaphore(10)
link_set = set()

def getlink(soup):
    items = soup.find_all('div', class_='list-products__item')
    links = []
    for item in items:
        a_tag = item.find('a')
        if a_tag and a_tag.get('href'):
            link = 'https://clickbuy.com.vn' + a_tag['href']
            links.append(link)
    return links

async def get_prd(session, i):
    url = f"https://clickbuy.com.vn/dien-thoai?page={i}"
    async with semaphore:
        try:
            await asyncio.sleep(0.5)
            async with session.get(url, timeout=15) as resp:
                if resp.status != 200:
                    print(f"❌ HTTP {resp.status} at page {i}")
                    return

                html = await resp.text()
                soup = BeautifulSoup(html, "html.parser")
                link_phones = getlink(soup)

                if not link_phones:
                    print(f"⚠️ No products found on page {i}")
                    return

                for link in link_phones:
                    if link not in link_set:
                        link_set.add(link)

                print(f"✅ Page {i} done. Added {len(link_phones)} products.")

        except Exception as e:
            print(f"⚠️ Error at page {i}: {e}")

async def main():
    async with aiohttp.ClientSession() as session:
        tasks = [get_prd(session, i) for i in range(1, 13)]
        await asyncio.gather(*tasks)

await main()
print(f"\n📦 Total product links collected: {len(link_set)}")
# Out:
# ✅ Page 1 done. Added 20 products.
# ✅ Page 6 done. Added 20 products.
# ✅ Page 9 done. Added 20 products.
# ✅ Page 5 done. Added 20 products.
# ✅ Page 10 done. Added 20 products.
# ✅ Page 7 done. Added 20 products.
# ✅ Page 4 done. Added 20 products.
# ✅ Page 3 done. Added 20 products.
# ✅ Page 8 done. Added 20 products.
# ✅ Page 2 done. Added 20 products.
# ✅ Page 11 done. Added 20 products.
# ✅ Page 12 done. Added 20 products.
#
# 📦 Total product links collected: 239

# %%
def info(soup):
    product = {}

    name_tag = soup.find('h1', class_="product-name")
    product_name = name_tag.get_text(strip=True) if name_tag else None

    price_new_tag = soup.find("p", class_="price")
    price_new_text = price_new_tag.get_text(strip=True) if price_new_tag else None

    price_old_tag = soup.find("p", class_="price-old")
    price_old_text = price_old_tag.get_text(strip=True) if price_old_tag else None

    product = {
        'Product_Name': product_name,
        'New_Price': price_new_text,
        'Old_Price': price_old_text
    }

    spec_section = soup.find("div", class_="product-specification__content")
    if spec_section:
        rows = spec_section.find_all("tr")
        for row in rows:
            th = row.find("th")
            td = row.find("td")
            if th and td:
                key = th.get_text(strip=True)
                value = td.get_text(strip=True)
                product[key] = value

    return product

# %%
semaphore = asyncio.Semaphore(10)

async def getinfo(session, i):
    async with semaphore:
        try:
            await asyncio.sleep(0.5)
            async with session.get(i, timeout=15) as resp:
                if resp.status != 200:
                    print(f"❌ HTTP {resp.status} at page {i}")
                    return

                html = await resp.text()
                soup = BeautifulSoup(html, "html.parser")
                phone = info(soup)
                products.append(phone)
                print(f"✅ Done products: {i}")

        except Exception as e:
            print(f"⚠️ Error at page {i}: {e}")

async def main():
    async with aiohttp.ClientSession() as session:
        tasks =
html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-s24.html
# ✅ Done products: https://clickbuy.com.vn/iphone-16e-512gb.html
# ✅ Done products: https://clickbuy.com.vn/realme-c60.html
# ✅ Done products: https://clickbuy.com.vn/realme-12.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-a05s-4g-4gb-128gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-s25-edge-12gb-256gb.html
# ✅ Done products: https://clickbuy.com.vn/redmi-13-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/iphone-se-3-2022-256gb.html
# ✅ Done products: https://clickbuy.com.vn/nokia-c32-4gb-128gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/apple-iphone-12-64gb-chinh-hang-vn-a.html
# ✅ Done products: https://clickbuy.com.vn/tecno-pova-6neo.html
# ✅ Done products: https://clickbuy.com.vn/vivo-z10-turbo-box.html
# ✅ Done products: https://clickbuy.com.vn/realme-14-5g-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/xiaomi-redmi-note-12-pro-4g-8gb-256gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/nubia-v60d.html
# ✅ Done products: https://clickbuy.com.vn/inoi-a75-8gb-512gb.html
# ✅ Done products: https://clickbuy.com.vn/nokia-105-4g-pro-2023-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/mobell-m539.html
# ✅ Done products: https://clickbuy.com.vn/iphone-16-pro.html
# ✅ Done products: https://clickbuy.com.vn/vivo-y19s-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-z-fold-7-512gb.html
# ✅ Done products: https://clickbuy.com.vn/iphone-se-3-2022-128gb.html
# ✅ Done products: https://clickbuy.com.vn/vivo-v50-lite-5g-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/xiaomi-redmi-note13-8gb-128gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/iphone-15-plus-256gb.html
# ✅ Done products: https://clickbuy.com.vn/nubia-red-magic-8-pro-plus-12gb-256gb-box.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-a13-5g.html
# ✅ Done products: https://clickbuy.com.vn/tecno-camon-30-12gb.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-s24-512gb.html
# ✅ Done products: https://clickbuy.com.vn/iphone-15-pro-max-512gb.html
# ✅ Done products: https://clickbuy.com.vn/vivo-x200-ultra-5g-box.html
# ✅ Done products: https://clickbuy.com.vn/xiaomi-redmi-a5-4gb-128gb.html
# ✅ Done products: https://clickbuy.com.vn/vivo-iqoo-z9-turbo-endurance-edition-2025-5g-box.html
# ✅ Done products: https://clickbuy.com.vn/infinix-hot-40i-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/galaxy-z-fold-6.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-a33.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-s25-plus.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-a35.html
# ✅ Done products: https://clickbuy.com.vn/xiaomi-redmi-note-14-4g-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-z-flip5-8gb-256gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/oppo-a78-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/tecno-pova-5-8gb-256gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/xiaomi-redmi-note-14-pro-plus-5g-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/vivo-y28-4g-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/galaxy-z-fold-6-1tb.html
# ✅ Done products: https://clickbuy.com.vn/tecno-spark-30c.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-z-flip5-8gb-512gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/nokia-110-ds-4g.html
# ✅ Done products: https://clickbuy.com.vn/xiaomi-redmi-13c.html
# ✅ Done products: https://clickbuy.com.vn/nokia-220-4g-2024.html
# ✅ Done products: https://clickbuy.com.vn/iphone-16-pro-512gb.html
# ✅ Done products: https://clickbuy.com.vn/iphone-14-plus-128gb-chinh-hang-vna.html
# ✅ Done products: https://clickbuy.com.vn/nubia-red-magic-9-pro.html
# ✅ Done products: https://clickbuy.com.vn/vivo-v30e.html
# ✅ Done products: https://clickbuy.com.vn/samsung-galaxy-a33-8gb-128gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/honor-x5b-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/masstel-izi-30.html
# ✅ Done products: https://clickbuy.com.vn/itel-it9310-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/vivo-iqoo-z9.html
# ✅ Done products: https://clickbuy.com.vn/realme-c55-4g-6gb-128gb-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/vivo-y100-chinh-hang.html
# ✅ Done products: https://clickbuy.com.vn/nubia-red-magic-8-pro-8gb-256gb-box.html
# ✅ Done products: https://clickbuy.com.vn/oppo-reno-12.html
# ✅ Done products: https://clickbuy.com.vn/dien-thoai-nokia-g11.html
#
# 📦 Total product links collected: 238/239

# %%
import pandas as pd
df = pd.DataFrame(products)

df.to_csv('../dataset/06.phone-new.csv', index=False, encoding='utf-8-sig')
