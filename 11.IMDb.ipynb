# %% [markdown]
# link = "https://www.imdb.com/chart/top/"

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import json
import pandas  as pd

# %%
driver = webdriver.Chrome()

url = "https://www.imdb.com/chart/top/"
driver.get(url)
time.sleep(3)

soup = BeautifulSoup(driver.page_source, "html.parser")

driver.quit()

# %%
script_tag = soup.find("script", id="__NEXT_DATA__")
json_data = json.loads(script_tag.string)

# Truy cập danh sách phim trong JSON
film_list = json_data["props"]["pageProps"]["pageData"]["chartTitles"]["edges"]

print(film_list)
# Out:
# [{'currentRank': 1, 'node': {'id': 'tt0111161', 'titleText': {'text': 'The Shawshank Redemption', '__typename': 'TitleText'}, 'titleType': {'id': 'movie', 'text': 'Movie', 'canHaveEpisodes': False, 'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, '__typename': 'TitleType'}, 'originalTitleText': {'text': 'The Shawshank Redemption', '__typename': 'TitleText'}, 'primaryImage': {'id': 'rm1690056449', 'width': 1200, 'height': 1800, 'url': 'https://m.media-amazon.com/images/M/MV5BMDAyY2FhYjctNDc5OS00MDNlLThiMGUtY2UxYWVkNGY2ZjljXkEyXkFqcGc@._V1_.jpg', 'caption': {'plainText': 'Tim Robbins in The Shawshank Redemption (1994)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'releaseYear': {'year': 1994, 'endYear': None, '__typename': 'YearRange'}, 'ratingsSummary': {'aggregateRating': 9.3, 'voteCount': 3061057, '__typename': 'RatingsSummary'}, 'runtime': {'seconds': 8520, '__typename': 'Runtime'}, 'certificate': {'rating': 'R', '__typename': 'Certificate'}, 'canRate': {'isRatable': True, '__typename': 'CanRate'}, 'titleGenres': {'genres': [{'genre': {'text': 'Drama', '__typename': 'GenreItem'}, '__typename': 'TitleGenre'}], '__typename': 'TitleGenres'}, 'series': None, 'latestTrailer': {'id': 'vi3877612057', '__typename': 'Video'}, 'plot': {'plotText': {'plainText': 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.', '__typename': 'Markdown'}, '__typename': 'Plot'}, 'releaseDate': {'day': 14, 'month': 10, 'year': 1994, '__typename': 'ReleaseDate'}, 'productionStatus': {'currentProductionStage': {'id': 'released', 'text': 'Released', '__typename': 'ProductionStage'}, '__typename': 'ProductionStatusDetails'}, '__typename': 'Title'}, '__typename': 'ChartTitleEdge'}, {'currentRank': 2, 'node': {'id': 'tt0068646', 'titleText': {'text': 'The Godfather', '__typename': 'TitleText'}, 'titleType': {'id': 'movie', 'text': 'Movie', 'canHaveEpisodes': False, 'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, '__typename': 'TitleType'}, 'originalTitleText': {'text': 'The Godfather', '__typename': 'TitleText'}, 'primaryImage': {'id': 'rm746868224', 'width': 1396, 'height': 1982, 'url': 'https://m.media-amazon.com/images/M/MV5BNGEwYjgwOGQtYjg5ZS00Njc1LTk2ZGEtM2QwZWQ2NjdhZTE5XkEyXkFqcGc@._V1_.jpg', 'caption': {'plainText': 'Marlon Brando in The Godfather (1972)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'releaseYear': {'year': 1972, 'endYear': None, '__typename': 'YearRange'}, 'ratingsSummary': {'aggregateRating': 9.2, 'voteCount': 2136649, '__typename': 'RatingsSummary'}, 'runtime': {'seconds': 10500, '__typename': 'Runtime'}, 'certificate': {'rating': 'R', '__typename': 'Certificate'}, 'canRate': {'isRatable': True, '__typename': 'CanRate'}, 'titleGenres': {'genres': [{'genre': {'text': 'Crime', '__typename': 'GenreItem'}, '__typename': 'TitleGenre'}, {'genre': {'text': 'Drama', '__typename': 'GenreItem'}, '__typename': 'TitleGenre'}], '__typename': 'TitleGenres'}, 'series': None, 'latestTrailer': {'id': 'vi1629995801', '__typename': 'Video'}, 'plot': {'plotText': {'plainText': 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.', '__typename': 'Markdown'}, '__typename': 'Plot'}, 'releaseDate': {'day': 24, 'month': 3, 'year': 1972, '__typename': 'ReleaseDate'}, 'productionStatus': {'currentProductionStage': {'id': 'released', 'text': 'Released', '__typename': 'ProductionStage'}, '__typename': 'ProductionStatusDetails'}, '__typename': 'Title'}, '__typename': 'ChartTitleEdge'}, {'currentRank': 3, 'node': {'id': 'tt0468569', 'titleText': {'text': 'The Dark Knight', '__typename': 'TitleText'}, 'titleType': {'id': 'movie', 'text': 'Movie', 'canHaveEpisodes': False, 'displayableProperty': {'value' ...

# %%
data = []
for film in film_list:
    rank = film["currentRank"]
    node = film["node"]
    title = node["titleText"]["text"]
    year = node["releaseYear"]["year"]
    rating = node["ratingsSummary"]["aggregateRating"]
    data.append({
        "Rank": rank,
        "Title": title,
        "Year": year,
        "Rating": rating
    })

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Rank                     Title  Year  Rating
# 0     1  The Shawshank Redemption  1994     9.3
# 1     2             The Godfather  1972     9.2
# 2     3           The Dark Knight  2008     9.0
# 3     4     The Godfather Part II  1974     9.0
# 4     5              12 Angry Men  1957     9.0

# %%
df.to_csv("11.imdb_top250.csv", index=False, encoding="utf-8-sig")

print("✅ Đã lưu dữ liệu vào file imdb_top250.csv")
# Out:
# ✅ Đã lưu dữ liệu vào file imdb_top250.csv
